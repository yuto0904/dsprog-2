# %% [markdown]
# # Python演習課題1

# %% [markdown]
# ## 課題1

# %% [markdown]
# ### 問1
#
# 文字列"datascience"の文字を逆に（末尾から先頭に向かって）並べた文字列を出力してください

# %%
s = "datascience"
reversed_s = s[::-1]
print(reversed_s)
# Out:
# ecneicsatad

# %% [markdown]
# ### 問2
#
# 「ヘエルスシトンニキア」という文字列の1,3,5,7,9文字目を取り出して連結した文字列を出力してください

# %%
s = "ヘエルスシトンニキア"
result = s[0] + s[2] + s[4] + s[6] + s[8]
print(result)
# Out:
# ヘルシンキ

# %% [markdown]
# ### 問3
#
# 「ヘルシンキ」＋「エストニア」の文字を先頭から交互に連結して文字列「ヘエルスシトンニキア」を出力してください

# %%
s1 = "ヘルシンキ"
s2 = "エストニア"

result = ""
for i in range(len(s1)):
    result += s1[i]
    result += s2[i]

print(result)
# Out:
# ヘエルスシトンニキア

# %% [markdown]
# ### 問4
#
# "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"という文を単語に分解し，各単語の（アルファベットの）文字数を先頭から出現順に並べたリストを作成してください

# %%
import re

sentence = "Character education based on the fundamental spirit of Buddhism and the Shiguzeigan"

# 単語に分解し、句読点を除去
words = re.findall(r'\b[a-zA-Z]+\b', sentence.lower()) # \bで単語の境界を、a-zA-Zでアルファベットのみを抽出

# 各単語の文字数をカウント
word_lengths = [len(word) for word in words]

print(word_lengths)
# Out:
# [9, 9, 5, 2, 3, 11, 6, 2, 8, 3, 3, 11]

# %% [markdown]
# ### 問5
#
# "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."という文を単語に分解し，1, 2, 5, 6, 8, 9, 16番目の単語の先頭の2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）を格納した辞書を作成してください

# %%
import re

sentence = "It is not the strongest of the species that survives, nor the most intelligent that survives. It is the one that is most adaptable to change."

# 単語に分解 (小文字化して句読点を除去)
# re.findall(r'\b[a-zA-Z]+\b', sentence.lower()) will extract words and convert them to lowercase
words = re.findall(r'[a-zA-Z]+', sentence.lower()) # アルファベットの連続を単語として抽出

# 抽出対象の単語の位置 (1-based)
target_indices_1based = [1, 2, 5, 6, 8, 9, 16]

result_dict = {}
for idx_1based in target_indices_1based:
    # 0-basedインデックスに変換
    idx_0based = idx_1based - 1
    if 0 <= idx_0based < len(words):
        word = words[idx_0based]
        # 先頭の2文字を取り出す
        if len(word) >= 2:
            prefix = word[:2]
            result_dict[prefix] = idx_1based
        elif len(word) == 1:
            # 1文字の単語の場合はその1文字を使用
            result_dict[word] = idx_1based

print(result_dict)
# Out:
# {'it': 1, 'is': 2, 'st': 5, 'of': 6, 'sp': 8, 'th': 9, 'su': 16}
